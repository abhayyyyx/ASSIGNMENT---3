# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as stats
import seaborn as sns

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## FIRST QUESTION - F&B MANAGER

# %%
cutlets = pd.read_csv(r"C:\Users\eabhaya\Desktop\EXCELR\Cutlets.csv")
cutlets.head()
# Out:
#    Unit A  Unit B
# 0  6.8090  6.7703
# 1  6.4376  7.5093
# 2  6.9157  6.7300
# 3  7.3012  6.7878
# 4  7.4488  7.1522

# %%
cutlets.describe()
# Out:
#           Unit A     Unit B
# count  35.000000  35.000000
# mean    7.019091   6.964297
# std     0.288408   0.343401
# min     6.437600   6.038000
# 25%     6.831500   6.753600
# 50%     6.943800   6.939900
# 75%     7.280550   7.195000
# max     7.516900   7.545900

# %%
cutlets.isnull().sum()
# Out:
# Unit A    0
# Unit B    0
# dtype: int64

# %%
cutlets.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# dtype: bool

# %%
cutlets[cutlets.duplicated()].shape
# Out:
# (0, 2)

# %%
cutlets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Unit A  35 non-null     float64
#  1   Unit B  35 non-null     float64
# dtypes: float64(2)
# memory usage: 692.0 bytes

# %%
plt.subplots(figsize = (10,6))
plt.subplot(121)
plt.boxplot(cutlets['Unit A'])
plt.title('Unit A')
plt.subplot(122)
plt.boxplot(cutlets['Unit B'])
plt.title('Unit B')
plt.show()

# %%
plt.subplots(figsize = (10,6))
plt.subplot(121)
plt.hist(cutlets['Unit A'])
plt.title('Unit A')
plt.subplot(122)
plt.hist(cutlets['Unit B'])
plt.title('Unit B')
plt.show()

# %%
plt.figure(figsize = (5,5))
label = (['Unit A','Unit B'])
sns.distplot(cutlets['Unit A'], kde = True)
sns.distplot(cutlets['Unit B'], hist=True)
plt.legend(label)

# %%
import statsmodels.api as sm

# %%
#plotting qq plot to determine the distribution
sm.qqplot(cutlets['Unit A'], line = 'r')
sm.qqplot(cutlets['Unit B'], line = 'r')
plt.show()

# %%
sta, pval = stats.ttest_ind(cutlets['Unit A'],cutlets['Unit B'],alternative='two-sided')
print('P value is :',pval)
# Out:
# P value is : 0.4722394724599501

# %%
#compare the p value with the given signifiance 5%
s = 0.025
print('signifiance:',s)
print("p value:",pval)
if pval<=s:
    print("We reject Null Hypothesis there is a significance difference between two Units A and B")
else:
    print("We fail to reject Null hypothesis")
# Out:
# signifiance: 0.025
# p value: 0.4722394724599501
# We fail to reject Null hypothesis

# %% [markdown]
# ## Question 2 - hospital turn around testing

# %%
lab = pd.read_csv(r"C:\Users\eabhaya\Desktop\EXCELR\LabTAT.csv")
lab.head(5)
# Out:
#    Laboratory 1  Laboratory 2  Laboratory 3  Laboratory 4
# 0        185.35        165.53        176.70        166.13
# 1        170.49        185.91        198.45        160.79
# 2        192.77        194.92        201.23        185.18
# 3        177.33        183.00        199.61        176.42
# 4        193.41        169.57        204.63        152.60

# %%
lab.describe()
# Out:
#        Laboratory 1  Laboratory 2  Laboratory 3  Laboratory 4
# count    120.000000    120.000000    120.000000     120.00000
# mean     178.361583    178.902917    199.913250     163.68275
# std       13.173594     14.957114     16.539033      15.08508
# min      138.300000    140.550000    159.690000     124.06000
# 25%      170.335000    168.025000    188.232500     154.05000
# 50%      178.530000    178.870000    199.805000     164.42500
# 75%      186.535000    189.112500    211.332500     172.88250
# max      216.390000    217.860000    238.700000     205.18000

# %%
lab.isnull().sum()
# Out:
# Laboratory 1    0
# Laboratory 2    0
# Laboratory 3    0
# Laboratory 4    0
# dtype: int64

# %%
lab[lab.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Laboratory 1, Laboratory 2, Laboratory 3, Laboratory 4]
# Index: []

# %%
lab.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Laboratory 1  120 non-null    float64
#  1   Laboratory 2  120 non-null    float64
#  2   Laboratory 3  120 non-null    float64
#  3   Laboratory 4  120 non-null    float64
# dtypes: float64(4)
# memory usage: 3.9 KB

# %%
plt.figure(figsize = (10,6))
plt.subplot(221)
plt.boxplot(lab['Laboratory 1'])
plt.title('Lab 1')
plt.subplot(222)
plt.boxplot(lab['Laboratory 2'])
plt.title('Lab 2')
plt.subplot(223)
plt.boxplot(lab['Laboratory 3'])
plt.title('Lab 3')
plt.subplot(224)
plt.boxplot(lab['Laboratory 4'])
plt.title('Lab 4')
plt.show()

# %%
plt.figure(figsize = (7,5))
plt.subplot(221)
plt.hist(lab['Laboratory 1'])
plt.title('Lab 1')
plt.subplot(222)
plt.hist(lab['Laboratory 2'])
plt.title('Lab 2')
plt.subplot(223)
plt.hist(lab['Laboratory 3'])
plt.title('Lab 3')
plt.subplot(224)
plt.hist(lab['Laboratory 4'])
plt.title('Lab 4')
plt.show()

# %%
plt.figure(figsize = (8,6))
labels = ['Lab 1', 'Lab 2','Lab 3', 'Lab 4']
sns.distplot(lab['Laboratory 1'],hist = True)
sns.distplot(lab['Laboratory 2'],hist = True)
sns.distplot(lab['Laboratory 3'],hist = True)
sns.distplot(lab['Laboratory 4'],hist = True)
plt.legend(labels)

# %%
sm.qqplot(lab['Laboratory 1'], line = 'r')
plt.title('Lab 1')
sm.qqplot(lab['Laboratory 2'], line = 'r')
plt.title('Lab 2')
sm.qqplot(lab['Laboratory 3'], line = 'r')
plt.title('Lab 3')
sm.qqplot(lab['Laboratory 4'], line = 'r')
plt.title('Lab 4')
plt.show()

# %%
sta1 , pval1 = stats.f_oneway(lab.iloc[:,0],lab.iloc[:,1],lab.iloc[:,2],lab.iloc[:,3])
print('p value =',pval)
# Out:
# p value = 0.4722394724599501

# %%
#compare the p value with the given signifiance 5%
s1 = 0.05
print('signifiance:',s1)
print("p value:",pval1)
if pval1<=s1:
    print("We reject Null Hypothesis there is a significance difference between two Units A and B")
else:
    print("We fail to reject Null hypothesis")
# Out:
# signifiance: 0.05
# p value: 2.1156708949992414e-57
# We reject Null Hypothesis there is a significance difference between two Units A and B

# %% [markdown]
# ## Question 3 : Hypothesis Testing Exercise

# %%
buyer_ratio = pd.read_csv(r"C:\Users\eabhaya\Desktop\ASSIGNMENTS  EXCELR\BuyerRatio.csv")
buyer_ratio.head()
# Out:
#   Observed Values  East  West  North  South
# 0           Males    50   142    131     70
# 1         Females   435  1523   1356    750

# %%
buyer_ratio.describe()
# Out:
#              East         West        North       South
# count    2.000000     2.000000     2.000000    2.000000
# mean   242.500000   832.500000   743.500000  410.000000
# std    272.236111   976.514465   866.205807  480.832611
# min     50.000000   142.000000   131.000000   70.000000
# 25%    146.250000   487.250000   437.250000  240.000000
# 50%    242.500000   832.500000   743.500000  410.000000
# 75%    338.750000  1177.750000  1049.750000  580.000000
# max    435.000000  1523.000000  1356.000000  750.000000

# %%
buyer_ratio.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Observed Values  2 non-null      object
#  1   East             2 non-null      int64
#  2   West             2 non-null      int64
#  3   North            2 non-null      int64
#  4   South            2 non-null      int64
# dtypes: int64(4), object(1)
# memory usage: 212.0+ bytes

# %%
buyer_ratio.isnull().sum()
# Out:
# Observed Values    0
# East               0
# West               0
# North              0
# South              0
# dtype: int64

# %%
buyer_ratio.duplicated()
# Out:
# 0    False
# 1    False
# dtype: bool

# %%
buyer_ratio[buyer_ratio.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Observed Values, East, West, North, South]
# Index: []

# %%
buyer_ratio.head()
# Out:
#   Observed Values  East  West  North  South
# 0           Males    50   142    131     70
# 1         Females   435  1523   1356    750

# %%
observed_value = np.array([[50,142,131,70],[435,1523,1356,750]])
observed_value
# Out:
# array([[  50,  142,  131,   70],
#        [ 435, 1523, 1356,  750]])

# %%
from scipy.stats import chi2_contingency

# %%
chi2_contingency(observed_value)
# Out:
# Chi2ContingencyResult(statistic=1.595945538661058, pvalue=0.6603094907091882, dof=3, expected_freq=array([[  42.76531299,  146.81287862,  131.11756787,   72.30424052],
#        [ 442.23468701, 1518.18712138, 1355.88243213,  747.69575948]]))

# %% [markdown]
# ## Question 4 : TeleCall uses 4 centers around the globe to process customer order forms.

# %%
cust = pd.read_csv(r"C:\Users\eabhaya\Desktop\ASSIGNMENTS  EXCELR\Costomer+OrderForm.csv")
cust.head()
# Out:
#   Phillippines   Indonesia       Malta       India
# 0   Error Free  Error Free   Defective  Error Free
# 1   Error Free  Error Free  Error Free   Defective
# 2   Error Free   Defective   Defective  Error Free
# 3   Error Free  Error Free  Error Free  Error Free
# 4   Error Free  Error Free   Defective  Error Free

# %%
cust.Phillippines.value_counts()
# Out:
# Phillippines
# Error Free    271
# Defective      29
# Name: count, dtype: int64

# %%
cust.Indonesia.value_counts()
# Out:
# Indonesia
# Error Free    267
# Defective      33
# Name: count, dtype: int64

# %%
cust.India.value_counts()
# Out:
# India
# Error Free    280
# Defective      20
# Name: count, dtype: int64

# %%
cust.Indonesia.value_counts()
# Out:
# Indonesia
# Error Free    267
# Defective      33
# Name: count, dtype: int64

# %%
ob = np.array([[271,267,280,267],[29,33,20,33]])
ob
# Out:
# array([[271, 267, 280, 267],
#        [ 29,  33,  20,  33]])

# %%
chi2_contingency(ob)
# Out:
# Chi2ContingencyResult(statistic=4.33740733319976, pvalue=0.22725982821249066, dof=3, expected_freq=array([[271.25, 271.25, 271.25, 271.25],
#        [ 28.75,  28.75,  28.75,  28.75]]))
